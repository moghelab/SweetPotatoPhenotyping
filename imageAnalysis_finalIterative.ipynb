# %%
import sys, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy import ndimage as ndi
from skimage.util import random_noise
from skimage import feature
from skimage.color import rgb2gray
from skimage.measure import label, regionprops, regionprops_table
from skimage.transform import rotate

from skimage import data
from skimage.exposure import histogram
from skimage import morphology
from skimage.restoration import denoise_nl_means

##############
def getLargestCC(segmentlabel):    
    assert( segmentlabel.max() != 0 ) # assume at least 1 CC
    largestCC = segmentlabel == np.argmax(np.bincount(segmentlabel.flat)[1:])+1
    return largestCC
##############

#Create empty pd dataframe
df = pd.DataFrame(columns = ['major_axis_length', 'minor_axis_length', 'bbox', 'filled_area', 
                                                'bbox_area','perimeter','extent'])

hline='\t'.join(['major_axis_length', 'minor_axis_length', 'bbox-0', 'bbox-1', 'bbox-2', 'bbox-3', 'filled_area', 
                                                'bbox_area','perimeter','extent', 'TotalWhiteRows', 'TotalWhiteCols'])
flist = os.listdir('Photos')
out1=open('extractedValues.tab','w')
out1.write(f'#File\tMaximumWidth\t{hline}\n')

for file in flist:    
    print ("Reading file: ", file); alist=[file]
    image = mpimg.imread(f'Photos/{file}')
    grayscale = rgb2gray (image)
    
    #Intensity histogram
    hist, hist_centers = histogram(grayscale)
    fillh = ndi.binary_fill_holes(grayscale<0.5) #Intensity filtering
    fillh2 = morphology.remove_small_objects(fillh, 100000) #Remove coins and tapes
    fillh3 = morphology.binary_opening(fillh2,  morphology.disk(20)) #Remove root hair
    fill_label = label(fillh3)
    largest = getLargestCC(fill_label)
    larlabel = label(largest)
    
    #Get maximum width
    edtimage = ndi.distance_transform_edt(larlabel)
    #pd.DataFrame(edtimage).to_csv('testOut.tab', sep="\t")
    maxdist = 2 * np.amax(edtimage)
    alist.append(str(maxdist))
    
    #Get other properties
    props = regionprops_table(larlabel,properties=('major_axis_length', 'minor_axis_length', 'bbox', 'filled_area', 
                                                'bbox_area','perimeter','extent'))
    
    #Extract values and write to out
    pkeys=list(props.keys());
    for i in range(0,len(pkeys)):
        key=pkeys[i]
        arr=props[key][0]; alist.append(str(arr))
    aline='\t'.join(alist)
    
    #Get distance based on axes
    pd.DataFrame(props)
    row1 = props['bbox-0'][0]; row2 = props['bbox-2'][0]
    col1 = props['bbox-2'][0]; col2 = props['bbox-3'][0]
    rows=abs(row1-row2)
    cols=abs(col1-col2)
    
    out1.write(f'{aline}\t{rows}\t{cols}\n')
out1.close()
print ("Done!")
# Out:
# Reading file:  PXL_20201223_175713470_rotated.jpg
# Reading file:  PXL_20201223_175851784_rotated.jpg
# Reading file:  PXL_20201223_175950974_rotated.jpg
# Reading file:  PXL_20201223_180037122_rotated.jpg
# Reading file:  PXL_20201223_180127238_rotated.jpg
# Reading file:  PXL_20201223_180322359.jpg
# Reading file:  PXL_20201223_180322359_rotated_rotated.jpg
# Reading file:  PXL_20201223_180355654.jpg
# Reading file:  PXL_20201223_180443749.jpg
# Reading file:  PXL_20201223_180539309.jpg
# Reading file:  PXL_20201223_180603417.jpg
# Reading file:  PXL_20201223_180642919.jpg
# Reading file:  PXL_20201223_180716002.jpg
# Reading file:  PXL_20201223_180745440.jpg
# Reading file:  PXL_20201223_180819583.jpg
# Reading file:  PXL_20201223_180903711.jpg
# Reading file:  PXL_20201223_180937937.jpg
# Reading file:  PXL_20201223_181016995.jpg
# Reading file:  PXL_20201223_181050833.jpg
# Reading file:  PXL_20201223_181121589.jpg
# Reading file:  PXL_20201223_181149482.jpg
# Reading file:  PXL_20201223_181217987.jpg
# Reading file:  PXL_20201223_181245454.jpg
# Reading file:  PXL_20201223_181314469.jpg
# Reading file:  PXL_20201223_181345981.jpg
# Reading file:  PXL_20201223_181424843.jpg
# Reading file:  PXL_20201223_181503658.jpg
# Reading file:  PXL_20201223_181535685.jpg
# Reading file:  PXL_20201223_181559669.jpg
# Reading file:  PXL_20201223_181634752.jpg
# Reading file:  PXL_20201223_181702306.jpg
# Reading file:  PXL_20201223_181734434.jpg
# Reading file:  PXL_20201223_181808782.jpg
# Reading file:  PXL_20201223_181843830.jpg
# Reading file:  PXL_20201223_182035564.jpg
# Reading file:  PXL_20201223_182108354.jpg
# Reading file:  PXL_20201223_182134388.jpg
# Reading file:  PXL_20201223_182159185.jpg
# Reading file:  PXL_20201223_182227334.jpg
# Reading file:  PXL_20201223_182300524.jpg
# Reading file:  PXL_20201223_182336379.jpg
# Reading file:  PXL_20201223_182412481.jpg
# Reading file:  PXL_20201223_185618063.jpg
# Reading file:  PXL_20201223_185711599.jpg
# Reading file:  PXL_20201223_185752662.jpg
# Reading file:  PXL_20201223_185827469.jpg
# Reading file:  PXL_20201223_185857450.jpg
# Reading file:  PXL_20201223_185929120.jpg
# Reading file:  PXL_20201223_190000637.jpg
# Reading file:  PXL_20201223_190024292.jpg
# Reading file:  PXL_20201223_190056884.jpg
# Reading file:  PXL_20201223_190233322.jpg
# Reading file:  PXL_20201223_190300286.jpg
# Reading file:  PXL_20201223_190328507.jpg
# Reading file:  PXL_20201223_190400491.jpg
# Reading file:  PXL_20201223_190439833.jpg
# Reading file:  PXL_20201223_190855970.jpg
# Reading file:  PXL_20201223_190926513.jpg
# Reading file:  PXL_20201223_191018405.jpg
# Reading file:  PXL_20201223_191109435.jpg
# Reading file:  PXL_20201223_191137841.jpg
# Reading file:  PXL_20201223_191207002.jpg
# Reading file:  PXL_20201223_191241677.jpg
# Reading file:  PXL_20201223_191315131.jpg
# Reading file:  PXL_20201223_191344039.jpg
# Reading file:  PXL_20201223_191416486.jpg
# Reading file:  PXL_20201223_192306096.jpg
# Reading file:  PXL_20201223_192343578.jpg
# Reading file:  PXL_20201223_192424860.jpg
# Reading file:  PXL_20201223_192503413.jpg
# Reading file:  PXL_20201223_192533295.jpg
# Reading file:  PXL_20201223_192601660.jpg
# Reading file:  PXL_20201223_192627292.jpg
# Reading file:  PXL_20201223_192658439.jpg
# Reading file:  PXL_20201223_192720322.jpg
# Reading file:  PXL_20201223_192754724.jpg
# Reading file:  PXL_20201223_192827662.jpg
# Reading file:  PXL_20201223_192859047.jpg
# Reading file:  PXL_20201223_192959206.jpg
# Reading file:  PXL_20201223_193031145.jpg
# Reading file:  PXL_20201223_193103016.jpg
# Reading file:  PXL_20201223_193136116.jpg
# Reading file:  PXL_20201223_193203244.jpg
# Reading file:  PXL_20201223_193257128.jpg
# Reading file:  PXL_20201223_194827189.jpg
# Reading file:  PXL_20201223_194902539.jpg
# Reading file:  PXL_20201223_194934710.jpg
# Reading file:  PXL_20201223_195005484.jpg
# Reading file:  PXL_20201223_195034793.jpg
# Reading file:  PXL_20201223_195104424.jpg
# Reading file:  PXL_20201223_195141022.jpg
# Reading file:  PXL_20201223_195233930.jpg
# Reading file:  PXL_20201223_195401828.jpg
# Reading file:  PXL_20201223_195434551.jpg
# Reading file:  PXL_20201223_195514203.jpg
# Reading file:  PXL_20201223_195546656.jpg
# Reading file:  PXL_20201223_195622932.jpg
# Reading file:  PXL_20201223_195654100.jpg
# Reading file:  PXL_20201223_195727269.jpg
# Reading file:  PXL_20201223_195755708.jpg
# Reading file:  PXL_20201223_195827817.jpg
# Reading file:  PXL_20201223_200415844_rotated.jpg
# Reading file:  PXL_20201223_200500595_rotated.jpg
# Reading file:  PXL_20201223_200526918_rotated.jpg
# Reading file:  PXL_20201223_200610313_rotated.jpg
# Reading file:  PXL_20201223_200649172_rotated.jpg
# Reading file:  PXL_20201223_200718610_rotated.jpg
# Reading file:  PXL_20201223_200746067_rotated.jpg
# Reading file:  PXL_20201223_200819200_rotated.jpg
# Reading file:  PXL_20201223_200852965_rotated.jpg
# Reading file:  PXL_20201223_201000035_rotated.jpg
# Reading file:  PXL_20201223_201101802_rotated.jpg
# Reading file:  PXL_20201223_201148524_rotated.jpg
# Reading file:  PXL_20201223_201217957_rotated.jpg
# Reading file:  PXL_20201226_204754669_rotated.jpg
# Reading file:  PXL_20201226_204838202_rotated.jpg
# Reading file:  PXL_20201226_204906657_rotated.jpg
# Reading file:  PXL_20201226_204931829_rotated.jpg
# Reading file:  PXL_20201226_205001064_rotated.jpg
# Reading file:  PXL_20201226_205026828_rotated.jpg
# Reading file:  PXL_20201226_205059844_rotated.jpg
# Reading file:  PXL_20201226_205136482_rotated.jpg
# Reading file:  PXL_20201226_205220355_rotated.jpg
# Reading file:  PXL_20201226_205257238_rotated.jpg
# Reading file:  PXL_20201226_205326245_rotated.jpg
# Reading file:  PXL_20201226_205357407_rotated.jpg
# Reading file:  PXL_20201226_205427928_rotated.jpg
# Reading file:  PXL_20201226_205457038_rotated.jpg
# Reading file:  PXL_20201226_205533332_rotated.jpg
# Reading file:  PXL_20201226_205559570_rotated.jpg
# Reading file:  PXL_20201226_205626393_rotated.jpg
# Reading file:  PXL_20201226_205701830_rotated.jpg
# Reading file:  PXL_20201226_205745566_rotated.jpg
# Reading file:  PXL_20201226_205830382_rotated.jpg
# Reading file:  PXL_20201226_205857435_rotated.jpg
# Reading file:  PXL_20201226_205927558_rotated.jpg
# Reading file:  PXL_20201226_205952378_rotated.jpg
# Reading file:  PXL_20201226_210017534_rotated.jpg
# Reading file:  PXL_20201226_210051709_rotated.jpg
# Reading file:  PXL_20201226_210132207_rotated.jpg
# Reading file:  PXL_20201226_210208456_rotated.jpg
# Reading file:  PXL_20201226_210235451_rotated.jpg
# Reading file:  PXL_20201226_210308585_rotated.jpg
# Reading file:  PXL_20201226_210405496_rotated.jpg
# Reading file:  PXL_20201226_210502823_rotated.jpg
# Reading file:  PXL_20201226_210533952_rotated.jpg
# Reading file:  PXL_20201226_210608814_rotated.jpg
# Reading file:  PXL_20201226_210638870_rotated.jpg
# Reading file:  PXL_20201226_210709799_rotated.jpg
# Reading file:  PXL_20201226_210741893_rotated.jpg
# Reading file:  PXL_20201226_210811177_rotated.jpg
# Reading file:  PXL_20201226_210939063_rotated.jpg
# Reading file:  PXL_20201226_211220838_rotated.jpg
# Reading file:  PXL_20201226_211307429_rotated.jpg
# Reading file:  PXL_20201226_211343053_rotated.jpg
# Reading file:  PXL_20201226_211410788_rotated.jpg
# Reading file:  PXL_20201226_211447215_rotated.jpg
# Reading file:  PXL_20201226_211516475_rotated.jpg
# Reading file:  PXL_20201226_211555482_rotated.jpg
# Reading file:  PXL_20201226_211624248_rotated.jpg
# Reading file:  PXL_20201226_211652665_rotated.jpg
# Reading file:  PXL_20201226_211721359_rotated.jpg
# Reading file:  PXL_20201226_211747344_rotated.jpg
# Reading file:  PXL_20201226_211816051_rotated.jpg
# Reading file:  PXL_20210104_190439725_rotated.jpg
# Reading file:  PXL_20210104_190618683_rotated.jpg
# Reading file:  PXL_20210104_190655076_rotated.jpg
# Reading file:  PXL_20210104_190734469_rotated.jpg
# Reading file:  PXL_20210104_190823580_rotated.jpg
# Reading file:  PXL_20210104_190859108_rotated.jpg
# Reading file:  PXL_20210104_190929660_rotated.jpg
# Reading file:  PXL_20210104_191001157_rotated.jpg
# Reading file:  PXL_20210104_191029269_rotated.jpg
# Reading file:  PXL_20210104_191055053_rotated.jpg
# Reading file:  PXL_20210104_191122819_rotated.jpg
# Reading file:  PXL_20210104_191301965_rotated.jpg
# Reading file:  PXL_20210104_191332333_rotated.jpg
# Reading file:  PXL_20210104_191419921_rotated.jpg
# Reading file:  PXL_20210104_191454387_rotated.jpg
# Reading file:  PXL_20210104_191522018_rotated.jpg
# Reading file:  PXL_20210104_191552561_rotated.jpg
# Reading file:  PXL_20210104_191623033_rotated.jpg
# Reading file:  PXL_20210104_191746691_rotated.jpg
# Reading file:  PXL_20210104_191822014_rotated.jpg
# Reading file:  PXL_20210104_191851191_rotated.jpg
# Reading file:  PXL_20210104_191918865_rotated.jpg
# Reading file:  PXL_20210104_191945656_rotated.jpg
# Reading file:  PXL_20210104_192008582_rotated.jpg
# Reading file:  PXL_20210104_192034219_rotated.jpg
# Reading file:  PXL_20210104_192059257_rotated.jpg
# Reading file:  PXL_20210104_192139373_rotated.jpg
# Reading file:  PXL_20210104_192207060_rotated.jpg
# Reading file:  PXL_20210104_192405167_rotated.jpg
# Reading file:  PXL_20210104_192432678_rotated.jpg
# Reading file:  PXL_20210104_192504533_rotated.jpg
# Reading file:  PXL_20210104_192533757_rotated.jpg
# Reading file:  PXL_20210104_192556540_rotated.jpg
# Reading file:  PXL_20210104_192621528_rotated.jpg
# Reading file:  PXL_20210104_192659407_rotated.jpg
# Reading file:  PXL_20210104_192735449_rotated.jpg
# Reading file:  PXL_20210104_192804058_rotated.jpg
# Reading file:  PXL_20210104_193313133_rotated.jpg
# Reading file:  PXL_20210104_193411026_rotated.jpg
# Reading file:  PXL_20210104_193441485_rotated.jpg
# Reading file:  PXL_20210104_193511961_rotated.jpg
# Reading file:  PXL_20210104_193550197_rotated.jpg
# Reading file:  PXL_20210104_193617061_rotated.jpg
# Reading file:  PXL_20210104_193644108_rotated.jpg
# Reading file:  PXL_20210104_193713347_rotated.jpg
# Reading file:  PXL_20210104_193737926_rotated.jpg
# Reading file:  PXL_20210104_193803153_rotated.jpg
# Reading file:  PXL_20210104_193836360_rotated.jpg
# Reading file:  PXL_20210104_193911282_rotated.jpg
# Reading file:  PXL_20210104_193953999_rotated.jpg
# Reading file:  PXL_20210104_194047410_rotated.jpg
# Reading file:  PXL_20210104_194125559_rotated.jpg
# Reading file:  PXL_20210104_194151204_rotated.jpg
# Reading file:  PXL_20210104_194223414_rotated.jpg
# Reading file:  PXL_20210104_194254293_rotated.jpg
# Reading file:  PXL_20210104_194321251_rotated.jpg
# Reading file:  PXL_20210104_194347146_rotated.jpg
# Reading file:  PXL_20210104_194415756_rotated.jpg
# Reading file:  PXL_20210104_194459100_rotated.jpg
# Reading file:  PXL_20210104_194523809_rotated.jpg
# Reading file:  PXL_20210104_194544396_rotated.jpg
# Reading file:  PXL_20210104_194608140_rotated.jpg
# Reading file:  PXL_20210104_194633865_rotated.jpg
# Reading file:  PXL_20210104_194656893_rotated.jpg
# Reading file:  PXL_20210104_194802946_rotated.jpg
# Reading file:  PXL_20210104_194829866_rotated.jpg
# Reading file:  PXL_20210104_194901931_rotated.jpg
# Reading file:  PXL_20210104_194925060_rotated.jpg
# Reading file:  PXL_20210104_194956464_rotated.jpg
# Reading file:  PXL_20210104_195022615_rotated.jpg
# Reading file:  PXL_20210104_195055334_rotated.jpg
# Reading file:  PXL_20210104_195123085_rotated.jpg
# Reading file:  PXL_20210104_195157548_rotated.jpg
# Reading file:  PXL_20210104_195300254_rotated.jpg
# Reading file:  PXL_20210104_195405424_rotated.jpg
# Reading file:  PXL_20210104_195909419_rotated.jpg
# Reading file:  PXL_20210104_200007366_rotated.jpg
# Reading file:  PXL_20210104_200241132_rotated.jpg
# Reading file:  PXL_20210104_200355505_rotated.jpg
# Reading file:  PXL_20210104_200425902_rotated.jpg
# Reading file:  PXL_20210104_200455282_rotated.jpg
# Reading file:  PXL_20210104_200528225_rotated.jpg
# Reading file:  PXL_20210104_200601459_rotated.jpg
# Reading file:  PXL_20210104_200654684_rotated.jpg
# Reading file:  PXL_20210104_200725874_rotated.jpg
# Reading file:  PXL_20210104_200755018_rotated.jpg
# Reading file:  PXL_20210104_200827937_rotated.jpg
# Reading file:  PXL_20210104_200855075_rotated.jpg
# Reading file:  PXL_20210104_200941734_rotated.jpg
# Reading file:  PXL_20210104_201008948_rotated.jpg
# Reading file:  PXL_20210104_201033877_rotated.jpg
# Reading file:  PXL_20210104_201114637_rotated.jpg
# Reading file:  PXL_20210104_201143437_rotated.jpg
# Reading file:  PXL_20210104_201210125_rotated.jpg
# Reading file:  PXL_20210104_201234038_rotated.jpg
# Reading file:  PXL_20210104_201310226_rotated.jpg
# Reading file:  PXL_20210104_201338522_rotated.jpg
# Reading file:  PXL_20210104_201359975_rotated.jpg
# Reading file:  PXL_20210104_201423945_rotated.jpg
# Reading file:  PXL_20210104_201445134_rotated.jpg
# Reading file:  PXL_20210104_201510529_rotated.jpg
# Reading file:  PXL_20210104_201531492_rotated.jpg
# Reading file:  PXL_20210104_201554661_rotated.jpg
# Reading file:  PXL_20210104_201615849_rotated.jpg
# Reading file:  PXL_20210104_201639830_rotated.jpg
# Done!
